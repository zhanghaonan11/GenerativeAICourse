# %% [markdown]
# # Building Real MCP Servers and Clients
#
# This notebook demonstrates building MCP servers using the official MCP SDK, then explains what happens under the hood.
#
# What we will demonstrate is creating an MCP Server that clients can consume (internal or external).
#
# Then we will build an MCP client that can connect to an MCP Server.
#
#
# ## Setup

# %%
# Install required packages - using the real MCP SDK
# !pip install "mcp[cli]" httpx "semantic-kernel[mcp]" python-dotenv
# Out:
# Requirement already satisfied: httpx in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (0.28.1)
# Requirement already satisfied: python-dotenv in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: mcp[cli] in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (1.10.1)
# Requirement already satisfied: semantic-kernel[mcp] in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (1.33.0)
# Requirement already satisfied: anyio>=4.5 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (4.9.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (2.9.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (2.11.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (2.3.6)
# Requirement already satisfied: starlette>=0.27 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (0.46.2)
# Requirement already satisfied: uvicorn>=0.23.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (0.34.2)
# Requirement already satisfied: typer>=0.12.4 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from mcp[cli]) (0.15.2)
# Requirement already satisfied: certifi in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from httpx) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from httpx) (1.0.8)
# Requirement already satisfied: idna in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from httpx) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx) (0.14.0)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.0.0b11)
# Requirement already satisfied: azure-ai-agents>=1.1.0b1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.1.0b2)
# Requirement already satisfied: aiohttp~=3.8 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (3.11.16)
# Requirement already satisfied: cloudevents~=1.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.12.0)
# Requirement already satisfied: defusedxml~=0.7 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.23.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (2.2.5)
# Requirement already satisfied: openai>=1.67 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.75.0)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.13.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.34.1)
# Requirement already satisfied: prance<25.4.9,>=23.6.21 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (25.4.8.0)
# Requirement already satisfied: pybars4~=0.9 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (1.15.3)
# Requirement already satisfied: protobuf in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (6.31.1)
# Requirement already satisfied: typing-extensions>=4.13 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from semantic-kernel[mcp]) (4.13.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiohttp~=3.8->semantic-kernel[mcp]) (1.20.0)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (0.10.1)
# Requirement already satisfied: av<15.0.0,>=14.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (14.4.0)
# Requirement already satisfied: cffi>=1.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (1.17.1)
# Requirement already satisfied: cryptography>=44.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (45.0.4)
# Requirement already satisfied: google-crc32c>=1.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (0.12.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aiortc>=1.9.0->semantic-kernel[mcp]) (25.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from anyio>=4.5->mcp[cli]) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-ai-agents>=1.1.0b1->semantic-kernel[mcp]) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-ai-agents>=1.1.0b1->semantic-kernel[mcp]) (1.34.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-ai-projects>=1.0.0b11->semantic-kernel[mcp]) (12.25.1)
# Requirement already satisfied: msal>=1.30.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-identity>=1.13->semantic-kernel[mcp]) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-identity>=1.13->semantic-kernel[mcp]) (1.3.1)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from cloudevents~=1.0->semantic-kernel[mcp]) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jinja2~=3.1->semantic-kernel[mcp]) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp[cli]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp[cli]) (0.24.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openai>=1.67->semantic-kernel[mcp]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openai>=1.67->semantic-kernel[mcp]) (0.9.0)
# Requirement already satisfied: tqdm>4 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openai>=1.67->semantic-kernel[mcp]) (4.67.1)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (0.3.4)
# Requirement already satisfied: more-itertools in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (10.7.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (0.7.2)
# Requirement already satisfied: parse in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (3.1.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from opentelemetry-api~=1.24->semantic-kernel[mcp]) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from opentelemetry-sdk~=1.24->semantic-kernel[mcp]) (0.55b1)
# Requirement already satisfied: chardet>=5.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.18.10 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (0.18.14)
# Requirement already satisfied: requests>=2.32.3 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (2.32.3)
# Requirement already satisfied: packaging>=24.2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (24.2)
# Requirement already satisfied: PyMeta3>=0.5.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from pybars4~=0.9->semantic-kernel[mcp]) (0.5.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.2->mcp[cli]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.2->mcp[cli]) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.2->mcp[cli]) (0.4.0)
# Requirement already satisfied: click>=8.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from typer>=0.12.4->mcp[cli]) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from typer>=0.12.4->mcp[cli]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from typer>=0.12.4->mcp[cli]) (14.0.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel[mcp]) (2.7.0)
# Requirement already satisfied: ifaddr>=0.2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel[mcp]) (0.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents>=1.1.0b1->semantic-kernel[mcp]) (1.17.0)
# Requirement already satisfied: pycparser in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic-kernel[mcp]) (2.22)
# Requirement already satisfied: zipp>=3.20 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel[mcp]) (3.23.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (6.0.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (0.4.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel[mcp]) (2.10.1)
# Requirement already satisfied: rfc3339-validator in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel[mcp]) (1.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer>=0.12.4->mcp[cli]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer>=0.12.4->mcp[cli]) (2.19.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from ruamel.yaml>=0.18.10->prance<25.4.9,>=23.6.21->semantic-kernel[mcp]) (0.2.12)
# Requirement already satisfied: mdurl~=0.1 in /Users/abdullahabuhassan/Desktop/gen-ai-course/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.4->mcp[cli]) (0.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import tempfile
import sys
from semantic_kernel import Kernel
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.connectors.mcp import MCPStdioPlugin
import os


from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

print("✅ Setup complete!")
# Out:
# ✅ Setup complete!

# %% [markdown]
# ## Part 1: Building a Real MCP Server (Using Official SDK)
#
# Since we are working in a Jupyter notebook, we will define the entire MCP server program as a string variable then write that string to a temporary file which becomes a runnable python script. Jupyter notebooks run in one python process, but MCP servers need to run as a separate process.
#
# We will use the official MCP SDK that will handle MCP protocol automatically.
#
# We will create an MCP server instance called weather.
#
# Then we will create a function to call NWS API to get weather information.
#
# mcp.tool() is the decorator where the magic happens. This registers the function as an MCP tool with the server. The FastMCP server automatically collects all decorated functions and makes them available through the MCP protocol.
#
# We have get alerts, get forecast, and get time.

# %%
# Create a weather MCP server using the official MCP SDK
weather_server_code = '''
from typing import Any
import httpx
from mcp.server.fastmcp import FastMCP

# Initialize FastMCP server
mcp = FastMCP("weather")

# Constants
NWS_API_BASE = "https://api.weather.gov"
USER_AGENT = "weather-app/1.0"

async def make_nws_request(url: str) -> dict[str, Any] | None:
    """Make a request to the NWS API with proper error handling."""
    headers = {
        "User-Agent": USER_AGENT,
        "Accept": "application/geo+json"
    }
    async with httpx.AsyncClient() as client:
        try:
            response = await client.get(url, headers=headers, timeout=30.0)
            response.raise_for_status()
            return response.json()
        except Exception:
            return None

def format_alert(feature: dict) -> str:
    """Format an alert feature into a readable string."""
    props = feature["properties"]
    return f"""
Event: {props.get('event', 'Unknown')}
Area: {props.get('areaDesc', 'Unknown')}
Severity: {props.get('severity', 'Unknown')}
Description: {props.get('description', 'No description available')}
Instructions: {props.get('instruction', 'No specific instructions provided')}
"""

@mcp.tool()
async def get_alerts(state: str) -> str:
    """Get weather alerts for a US state.

    Args:
        state: Two-letter US state code (e.g. CA, NY)
    """
    url = f"{NWS_API_BASE}/alerts/active/area/{state}"
    data = await make_nws_request(url)

    if not data or "features" not in data:
        return "Unable to fetch alerts or no alerts found."

    if not data["features"]:
        return "No active alerts for this state."

    alerts = [format_alert(feature) for feature in data["features"]]
    return "\\n---\\n".join(alerts)

@mcp.tool()
async def get_forecast(latitude: float, longitude: float) -> str:
    """Get weather forecast for a location.

    Args:
        latitude: Latitude of the location
        longitude: Longitude of the location
    """
    # First get the forecast grid endpoint
    points_url = f"{NWS_API_BASE}/points/{latitude},{longitude}"
    points_data = await make_nws_request(points_url)

    if not points_data:
        return "Unable to fetch forecast data for this location."

    # Get the forecast URL from the points response
    forecast_url = points_data["properties"]["forecast"]
    forecast_data = await make_nws_request(forecast_url)

    if not forecast_data:
        return "Unable to fetch detailed forecast."

    # Format the periods into a readable forecast
    periods = forecast_data["properties"]["periods"]
    forecasts = []
    for period in periods[:5]:  # Only show next 5 periods
        forecast = f"""
{period['name']}:
Temperature: {period['temperature']}°{period['temperatureUnit']}
Wind: {period['windSpeed']} {period['windDirection']}
Forecast: {period['detailedForecast']}
"""
        forecasts.append(forecast)

    return "\\n---\\n".join(forecasts)

@mcp.tool()
async def get_time() -> str:
    """Get the current time for demo purposes."""
    from datetime import datetime
    return f"Current time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"

if __name__ == "__main__":
    # This single line starts the entire MCP server!
    mcp.run(transport='stdio')
'''

# Save the real MCP server to a file
with tempfile.NamedTemporaryFile(mode='w', suffix='_weather_server.py', delete=False) as f:
    f.write(weather_server_code)
    weather_server_path = f.name

print(f"✅ Created real MCP weather server at: {weather_server_path}")
print("\n🌦️  This server uses the OFFICIAL MCP SDK and provides:")
print("  • get_alerts(state) - Get weather alerts for US states")
print("  • get_forecast(latitude, longitude) - Get weather forecast")
print("  • get_time() - Get current time (for demo)")
# Out:
# ✅ Created real MCP weather server at: /var/folders/qr/gx2vdzd12tn4dd7g_hgdg_q00000gn/T/tmp0b2yxk5w_weather_server.py
#
# 🌦️  This server uses the OFFICIAL MCP SDK and provides:
#   • get_alerts(state) - Get weather alerts for US states
#   • get_forecast(latitude, longitude) - Get weather forecast
#   • get_time() - Get current time (for demo)

# %% [markdown]
# ## Part 2: Connect Semantic Kernel Agent to Real MCP Server
#
# This creates an AI agent that can connect to our MCP weather server. We will use Semantic Kernel like before to connect to this MCP server.
#
# We use MCPStdioPlugin which is Semantic Kernel’s connector for MCP servers. We register it as a plugin, then provide it as a plugin to Semantic Kernel.
#
# What happens under the hood:
#
# When you use the mcp.tool() decorator, under the hood, the FastMCP library registers the function, parses the name and description. This is the magic that transforms your simple python function into an MCP tool that any MCP client can discover.
#
# mcp.run() creates an infinite loop that constantly waits for messages from clients.
#
# In real world scenarios, we would connect to databases, CRM systems, and other production systems.

# %%
async def demo_real_mcp_server():
    """Connect to our real MCP server using Semantic Kernel."""
    
    if OPENAI_API_KEY == "your-openai-api-key-here":
        print("⚠️  Please set your OpenAI API key!")
        return
    
    # Create kernel with OpenAI service
    kernel = Kernel()
    chat_service = OpenAIChatCompletion(
        ai_model_id="gpt-4o-mini",
        api_key=OPENAI_API_KEY
    )
    kernel.add_service(chat_service)
    
    try:
        # Connect to our REAL MCP server
        print("🔌 Connecting to real MCP weather server...")
        
        async with MCPStdioPlugin(
            name="RealWeather",
            description="Real weather server using official MCP SDK",
            command=sys.executable,
            args=[weather_server_path],
            load_tools=True,
            load_prompts=False,
            request_timeout=30
        ) as weather_plugin:
            
            # Add MCP plugin to kernel
            kernel.add_plugin(weather_plugin)
            print("✅ Connected to real MCP server!")
            
            # Add MCP plugin to kernel
            kernel.add_plugin(weather_plugin)
            print("✅ Connected to real MCP server!")
            
            # Show that tools are available (we'll see them in action)
            print(f"\n🔧 MCP Server Connected:")
            print(f"  • Server: {weather_plugin.name}")
            print(f"  • Tools: Available via MCP protocol")
            print(f"  • Ready to use: get_alerts, get_forecast, get_time")
            
            # Create weather agent
            agent = ChatCompletionAgent(
                kernel=kernel,
                name="WeatherAgent",
                instructions="""
                You are a helpful weather assistant with access to real weather data via MCP.
                
                You can:
                - get_alerts: Get weather alerts for US states (use 2-letter codes like CA, NY, TX)
                - get_forecast: Get detailed forecasts for specific coordinates
                - get_time: Get current time
                
                Always provide helpful, accurate information using your MCP tools.
                """
            )
            
            # Test the real MCP server
            print(f"\n🌦️  Testing Real MCP Weather Server:")
            print("=" * 45)
            
            test_queries = [
                "What time is it?",
                "Are there any weather alerts in California?",
                "Get me the forecast for Sacramento (latitude 38.5816, longitude -121.4944)"
            ]
            
            for i, query in enumerate(test_queries, 1):
                print(f"\n{i}. 👤 User: {query}")
                
                try:
                    response = await agent.get_response(query)
                    print(f"   🤖 Agent: {response.content}")
                except Exception as e:
                    print(f"   ❌ Error: {e}")
            
    except Exception as e:
        print(f"❌ Real MCP connection failed: {e}")
        print("📝 Note: This requires internet access for weather API calls")

# Run the real MCP demo
await demo_real_mcp_server()
# Out:
# 🔌 Connecting to real MCP weather server...
# ✅ Connected to real MCP server!
# ✅ Connected to real MCP server!
#
# 🔧 MCP Server Connected:
#   • Server: RealWeather
#   • Tools: Available via MCP protocol
#   • Ready to use: get_alerts, get_forecast, get_time
#
# 🌦️  Testing Real MCP Weather Server:
# =============================================
#
# 1. 👤 User: What time is it?
#    🤖 Agent: The current time is 17:49:24 on June 27, 2025.
#
# 2. 👤 User: Are there any weather alerts in California?
#    🤖 Agent: There are currently no active weather alerts in California.
#
# 3. 👤 User: Get me the forecast for Sacramento (latitude 38.5816, longitude -121.4944)
#    🤖 Agent: Here's the weather forecast for Sacramento (latitude 38.5816, longitude -121.4944):
#
# **Today:**
# - Temperature: 97°F
# - Wind: 2 to 6 mph SW
# - Forecast: Sunny, with a high near 97.
#
# ---
#
# **Tonight:**
# - Temperature: 66°F
# - Wind: 2 to 6 mph SSW
# - Forecast: Clear, with a low around 66.
#
# ---
#
# **Saturday:**
# - Temperature: 100°F
# - Wind: 2 to 9 mph SSW
# - Forecast: Sunny. High near 100, with temperatures falling to around 98 in the afternoon.
#
# ---
#
# **Saturday Night:**
# - Temperature: 63°F
# - Wind: 5 to 9 mph SSW
# - Forecast: Clear, with a low around 63.
#
# ---
#
# **Sunday:**
# - Temperature: 97°F
# - Wind: 3 to 10 mph SSW
# - Forecast: Sunny, with a high near 97.
#
# If you need more information or updates, feel free to ask!
